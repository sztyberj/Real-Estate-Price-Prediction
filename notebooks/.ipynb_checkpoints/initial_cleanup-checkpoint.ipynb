# %% [markdown]
# # initial cleanup

# %%
import pandas as pd
import numpy as np
import re

# %%
#Pipeline functions

def cl_price(df):
    #price
    print("clean price")
    df['price'] = df['price'].str.replace(r"[^\d]", "", regex=True)
    df["price"] = df["price"].replace("", np.nan).astype("Int64")

    return df

def cl_ppm(df):
    #ppm
    print("clean ppm")
    df['price_per_meter'] = df['price_per_meter'].str.replace(r"[^\d]", "", regex=True)

    return df

def cl_floor(df):
    #floor
    print("clean floor")
    df["floor"] = df["floor"].str.split("/").str[0]
    df.loc[df["floor"].astype(str).str.lower().str.contains("parter", na=False), "floor"] = 0

    return df

def cl_furnished(df):
    #furnished
    print("clean furnished")
    df["furnished"] = df["furnished"].replace({"Tak": 1, "Nie": 0}).astype("Int64")

    return df

def cl_adress(df):
    #adress
    print("clean adress")
    address_parts = df["district"].str.split(",", expand=True)
    
    address_parts = address_parts.applymap(lambda x: x.strip() if isinstance(x, str) else x)
    mask = address_parts.iloc[:, 2].str.lower() == "mazowieckie"
    address_parts.loc[mask, [4, 3, 2, 1]] = address_parts.loc[mask, [3, 2, 1, 0]].values
    
    del address_parts[4]
    address_parts.columns = ["street", "neighbourhood", "district", "voivodeship"]
    address_parts
    df = df.join(address_parts, rsuffix="_new")
    
    del df['district']

    return df

# %%
data_oto = pd.read_csv("../data/raw/raw_otodom_selenium_23032025211344.csv", sep=';')

def oto_cleanup_pipeline(df):
    df = cl_price(df)
    df = cl_ppm(df)
    df = cl_floor(df)
    df = cl_furnished(df)
    df = cl_adress(df)

    return df

data_oto = oto_cleanup_pipeline(data_oto)
data_oto.head(5)
# Out:
# clean price
# clean ppm
# clean floor
# clean furnished
# clean adress
# C:\Users\Jakub\AppData\Local\Temp\ipykernel_1176\2591618256.py:29: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["furnished"] = df["furnished"].replace({"Tak": 1, "Nie": 0}).astype("Int64")
# C:\Users\Jakub\AppData\Local\Temp\ipykernel_1176\2591618256.py:38: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   address_parts = address_parts.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#    source    price price_per_meter   area  rooms floor market_type  furnished  \
# 0  otodom  1409000           17617  79.98    4.0     0   pierwotny          1
# 1  otodom  1495000           21083  70.91    3.0     3      wtórny          1
# 2  otodom   685000           22154  30.92    2.0   NaN      wtórny          1
# 3  otodom     <NA>             NaN  66.10    3.0     0   pierwotny          1
# 4  otodom   768000           12800  60.00    4.0   NaN   pierwotny          1
#
#                                          description        date  \
# 0  4-pokojowe mieszkanie numer 4 na parterze w bu...  2025-03-23
# 1                                                NaN  2025-03-23
# 2                                                NaN  2025-03-22
# 3  3-pokojowe mieszkanie numer B001 na parterze w...  2025-03-23
# 4                                                NaN  2025-03-23
#
#                                                  url  \
# 0  https://www.otodom.pl/pl/oferta/4-pokojowe-mie...
# 1  https://www.otodom.pl/pl/oferta/wilanow-70-91-...
# 2  https://www.otodom.pl/pl/oferta/2024r-sypialni...
# 3  https://www.otodom.pl/pl/oferta/3-pokojowe-mie...
# 4  https://www.otodom.pl/pl/oferta/4-pok-w-znakom...
#
#                                                title              street  \
# 0               4-pokojowe mieszkanie 79m2 + ogródek         ul. Gratyny
# 1       Wilanów, 70,91 m2, 3/4 pokoje, garaż, balkon  Błonia Wilanowskie
# 2         2024r, sypialnia, ładne osiedle. Blisko M3   ul. Podskarbińska
# 3  3-pokojowe mieszkanie 66m2 + ogródek Bezpośrednio          ul. Polska
# 4                4 pok. w znakomitej cenie , OGRÓDEK  ul. Posag 7 Panien
#
#         neighbourhood    district_new  voivodeship
# 0     Kępa Zawadowska         Wilanów  mazowieckie
# 1  Błonia Wilanowskie         Wilanów  mazowieckie
# 2             Grochów  Praga-Południe  mazowieckie
# 3           Siekierki         Mokotów  mazowieckie
# 4             Szamoty           Ursus  mazowieckie

# %%
data_olx = pd.read_csv("../data/raw/raw_olx_23032025155859.csv", sep=';')

def oto_cleanup_pipeline(df):
    df = cl_price(df)
    df = cl_ppm(df)
    df = cl_floor(df)
    df = cl_furnished(df)

    return df

data_olx = oto_cleanup_pipeline(data_olx)
data_olx.head(5)
# Out:
# clean price
# clean ppm
# clean floor
# clean furnished
#      price price_per_meter   area  rooms floor market_type  furnished  \
# 0  1249000         1864179     67    4.0    10      Wtórny       <NA>
# 1   699000         1294444     54    3.0     0      Wtórny       <NA>
# 2   378000           15120     25    1.0     1      Wtórny       <NA>
# 3   739000         1919481  38,50    2.0    10      Wtórny       <NA>
# 4   580000         1903512  30,47    2.0     6      Wtórny       <NA>
#
#      building_type                                        description  \
# 0             Blok  OPIS\nSPRZEDAJE WAŚCICIEL\nMieszkanie położne ...
# 1  Apartamentowiec  OPIS\nDo sprzedaży przestronne mieszkanie na O...
# 2             Blok  OPIS\nNa sprzedaż nowy lokal / mikro-kawalerka...
# 3             Blok  OPIS\nDo sprzedania dwupokojowe mieszkanie prz...
# 4             Blok  OPIS\nDo sprzedania mieszkanie które świetnie ...
#
#          district        date  \
# 0         Mokotów  2025-03-16
# 1       Białołęka         NaN
# 2          Włochy  2025-03-22
# 3  Praga-Południe  2025-03-21
# 4            Wola  2025-03-22
#
#                                                  url
# 0  https://www.olx.pl/d/oferta/mokotow-4-pokoje-n...
# 1  https://www.olx.pl/d/oferta/idealne-mieszkanie...
# 2  https://www.olx.pl/d/oferta/nowa-kawalerka-swi...
# 3  https://www.olx.pl/d/oferta/gotowe-do-wprowadz...
# 4  https://www.olx.pl/d/oferta/mieszkanie-dwa-pok...
